# %% [markdown]
# # DicomStructureFile Class Demonstration
#
# This notebook demonstrates the functionality of the `DicomStructureFile` class
# using a collection of DICOM RT Structure file.
#
# ## Overview
# The `DicomStructureFile` class provides a convenient interface for:
# - Loading DICOM RT Structure files
# - Extracting structure information and metadata
# - Reading contour sequences and converting them to ContourPoints
# - Creating a sequence of ContourPoints, used by the StructureSet class

# %% [markdown]
# ## 1. Import Required Libraries
#
# First, let's import the necessary libraries including our custom DicomStructureFile class.

# %%
# Import required libraries
from typing import List, Tuple
#import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import shapely

# Add the src directory to the Python path
#sys.path.append('src')

# Import our custom DicomStructureFile class
from dicom import DicomStructureFile

# Import related classes
from types_and_classes import SliceIndexType
from contours import ContourPoints
from structure_set import StructureSet
from relations import RelationshipType

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# %matplotlib inline

# %% [markdown]
# ## 2. Load the DICOM Structure File
#
# Set the path to your DICOM RT Structure file.

# %%
# Define the path to the test DICOM file
tests_dir = Path.cwd() / r'Tests'
tests_dir = tests_dir.resolve()

# %% [markdown]
# The test directory contains several DICOM RT Structure files for demonstration purposes.

# %%
[file.name for file in tests_dir.glob('*.dcm')]
# Out:
# ['CT.BREL_TEST.Image 1.dcm',
#  'CT.BREL_TEST.Image 135.dcm',
#  'CT.BREL_TEST.Image 70.dcm',
#  'RS.1.2.246.352.221.506802614516650949923693429510578325.dcm',
#  'RS.BREL_TEST.BREL BH.dcm',
#  'RS.GJS_Struct_Tests.BRBL BH.dcm',
#  'RS.GJS_Struct_Tests.MultiVolume_A (1).dcm',
#  'RS.GJS_Struct_Tests.MultiVolume_A (2).dcm',
#  'RS.GJS_Struct_Tests.MultiVolume_A.dcm',
#  'RS.GJS_Struct_Tests.Relations.dcm',
#  'RS.GJS_Struct_Tests.ResolutionChecks.dcm',
#  'RS.GJS_Struct_Tests.Surrounding.dcm',
#  'RS.NormalTissueTest.SPIL2.dcm']

# %% [markdown]
# Select one of the files to load.

# %%
test_file_name = "RS.GJS_Struct_Tests.MultiVolume_A (1).dcm"
#test_file_name = "RS.GJS_Struct_Tests.Relations.dcm"

# %% [markdown]
# Now let's load the test DICOM RT Structure file using the DicomStructureFile class.

# %%
# Load the DICOM structure file using file_name parameter
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)

print(f"Successfully loaded: {dicom_file}")
print(f"File name: {dicom_file.file_name}")
print(f"Is RT Structure file: {dicom_file.is_structure_file()}")
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# INFO:dicom:Extracted 730 contours from 7 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# Successfully loaded: DICOM RT Structure: MultiVolume_A for patient GJS_Struct_Tests
# File name: RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# Is RT Structure file: True

# %% [markdown]
# ## 3. Explore Structure File Properties
#
# Let's examine the basic properties and metadata of the loaded DICOM structure file.

# %%
# Get structure file information
structure_info = dicom_file.get_structure_set_info()

print("=== DICOM Structure File Information ===")
for key, value in structure_info.items():
    if key == 'File':
        print(f"File name: {value.name}")
    else:
        print(f"{key}: {value}")

# Access some basic DICOM dataset attributes
dataset = dicom_file.dataset
print("\n=== Additional DICOM Attributes ===")
print(f"Modality: {getattr(dataset, 'Modality', 'Not available')}")
print(f"Study Date: {getattr(dataset, 'StudyDate', 'Not available')}")
print(f"Manufacturer: {getattr(dataset, 'Manufacturer', 'Not available')}")
print(f"Software Version: {getattr(dataset, 'SoftwareVersions', 'Not available')}")

# Check if ROI contour sequence exists
if hasattr(dataset, 'ROIContourSequence'):
    print(f"\nNumber of ROI Contours: {len(dataset.ROIContourSequence)}")
else:
    print("\nNo ROI Contour Sequence found")
# Out:
# === DICOM Structure File Information ===
# PatientName: StructureVolumes^Test
# PatientLastName: StructureVolumes
# PatientID: GJS_Struct_Tests
# StructureSet: MultiVolume_A
# StudyID: Phantom2
# SeriesNumber: 9
# File name: RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
#
# === Additional DICOM Attributes ===
# Modality: RTSTRUCT
# Study Date: 20240218
# Manufacturer: Varian Medical Systems
# Software Version: 4.2.7.0
#
# Number of ROI Contours: 7

# %% [markdown]
# ## 4. Access Structure Set Information
#
# Let's examine the structure set and ROI information in more detail.

# %%
# Examine the Structure Set ROI Sequence
if hasattr(dataset, 'StructureSetROISequence'):
    print("=== Structure Set ROI Information ===")
    roi_info = []
    for i, roi in enumerate(dataset.StructureSetROISequence):
        roi_data = {
            'ROI Number': getattr(roi, 'ROINumber', 'N/A'),
            'ROI Name': getattr(roi, 'ROIName', 'N/A'),
            'ROI Generation Algorithm': getattr(roi, 'ROIGenerationAlgorithm', 'N/A')
        }
        roi_info.append(roi_data)
        if i < 3:  # Limit output to first 3 ROIs for brevity
            print(f"\nROI {i+1}:")
            for key, value in roi_data.items():
                print(f"  {key}: {value}")
        elif i == 3:
            print(f"... (and {len(dataset.StructureSetROISequence) - 3} more ROIs)")

    # Convert to DataFrame for easier viewing
    roi_df = pd.DataFrame(roi_info)
    print("\n=== ROI Summary Table ===")
    print(roi_df.to_string(index=False))
else:
    print("No Structure Set ROI Sequence found")
# Out:
# === Structure Set ROI Information ===
#
# ROI 1:
#   ROI Number: 1
#   ROI Name: BODY
#   ROI Generation Algorithm: MANUAL
#
# ROI 2:
#   ROI Number: 7
#   ROI Name: OverlappedSphere
#   ROI Generation Algorithm: MANUAL
#
# ROI 3:
#   ROI Number: 8
#   ROI Name: OverlappedShells
#   ROI Generation Algorithm: MANUAL
# ... (and 4 more ROIs)
#
# === ROI Summary Table ===
#  ROI Number         ROI Name ROI Generation Algorithm
#           1             BODY                   MANUAL
#           7 OverlappedSphere                   MANUAL
#           8 OverlappedShells                   MANUAL
#           9        Surrounds                   MANUAL
#          10           Embeds                   MANUAL
#          13   PartialEmbeded                   MANUAL
#          12  PartialSurround                   MANUAL

# %% [markdown]
# ## 5. Extract ROI Contour Data
#
# Now let's use our custom method to extract contour data and convert it to ContourPoints objects.

# %%
# Extract contour sequences using our custom method
contour_points = dicom_file.get_contour_points()

print(f"=== Contour Extraction Results ===")
print(f"Total ContourPoints objects created: {len(contour_points)}")

# Examine the first few contour points
if contour_points:
    print(f"\n=== Sample ContourPoints Objects ===")
    for i, cp in enumerate(contour_points[:3]):  # Show first 3
        print(f"\nContourPoint {i+1}:")
        print(f"  ROI Number: {cp['ROI']}")
        print(f"  Slice Index: {cp['Slice']}")
        print(f"  Number of Points: {len(cp['Points']) if cp['Points'] else 0}")
        if cp['Points'] and len(cp['Points']) > 0:
            print(f"  First point: {cp['Points'][0]}")
            print(f"  Last point: {cp['Points'][-1]}")
# Out:
# INFO:dicom:Extracted 730 contours from 7 ROIs
# === Contour Extraction Results ===
# Total ContourPoints objects created: 730
#
# === Sample ContourPoints Objects ===
#
# ContourPoint 1:
#   ROI Number: 1
#   Slice Index: -10.0
#   Number of Points: 680
#   First point: [ -9.902  -9.906 -10.   ]
#   Last point: [ -9.906  -9.902 -10.   ]
#
# ContourPoint 2:
#   ROI Number: 1
#   Slice Index: -9.9
#   Number of Points: 680
#   First point: [ -9.902 -10.001  -9.9  ]
#   Last point: [-10.001  -9.902  -9.9  ]
#
# ContourPoint 3:
#   ROI Number: 1
#   Slice Index: -9.8
#   Number of Points: 680
#   First point: [ -9.902 -10.001  -9.8  ]
#   Last point: [-10.001  -9.902  -9.8  ]

# %%
if contour_points:
    # Show statistics by ROI
    roi_counts = {}
    for cp in contour_points:
        roi_num = cp['ROI']
        if roi_num not in roi_counts:
            roi_counts[roi_num] = {'slices': 0, 'total_points': 0}
        roi_counts[roi_num]['slices'] += 1
        if cp['Points']:
            roi_counts[roi_num]['total_points'] += len(cp['Points'])

    print(f"\n=== Contour Statistics by ROI ===")
    for roi_num, stats in roi_counts.items():
        print(f"ROI {roi_num}: {stats['slices']} slices, {stats['total_points']} total points")

else:
    print("No contour points found in the dataset")
# Out:
# === Contour Statistics by ROI ===
# ROI 1: 201 slices, 136680 total points
# ROI 7: 98 slices, 13386 total points
# ROI 8: 176 slices, 21814 total points
# ROI 9: 118 slices, 21320 total points
# ROI 10: 29 slices, 2390 total points
# ROI 13: 27 slices, 1304 total points
# ROI 12: 81 slices, 14144 total points

# %% [markdown]
# ## 9. Integration with StructureSet Class
# Now let's demonstrate how to use the DicomStructureFile with the StructureSet class to analyze structure relationships.

# %%
print("=== Creating StructureSet from DicomStructureFile ===")

# Method 1: Using DicomStructureFile (recommended approach)
structure_set = StructureSet(dicom_structure_file=dicom_file)

print(f"Successfully created StructureSet with {len(structure_set.structures)} structures")
# Out:
# INFO:structure_set:Building StructureSet from 730 contour points
# === Creating StructureSet from DicomStructureFile ===
# Successfully created StructureSet with 7 structures

# %%
# Display the structures that were loaded
print("\n=== Loaded Structures ===")
for roi, structure in structure_set.structures.items():
    print(f"ROI {roi}: {structure.name}")
# Out:
# === Loaded Structures ===
# ROI 1: BODY
# ROI 7: OverlappedSphere
# ROI 8: OverlappedShells
# ROI 9: Surrounds
# ROI 10: Embeds
# ROI 12: PartialSurround
# ROI 13: PartialEmbeded

# %%
# Get basic structure information
print("=== Structure Summary ===")
structure_summary = structure_set.summary()
volumes = ['Physical_Volume', 'Exterior_Volume', 'Hull_Volume']
for col in volumes:
    if col in structure_summary.columns:
        structure_summary[col] = structure_summary[col].round(1)
print(structure_summary.to_string(index=False))
# Out:
# === Structure Summary ===
#  ROI             Name  Physical_Volume  Exterior_Volume  Hull_Volume  Num_Contours  Num_Slices
#    1             BODY           8599.8           8599.8       8599.8           217         217
#    7 OverlappedSphere            136.2            136.2        136.4           106          53
#    8 OverlappedShells             70.3            137.8        138.1           194          55
#    9        Surrounds            266.4            302.0        302.6           137          90
#   10           Embeds             14.4             14.4         14.4            33          33
#   12  PartialSurround            149.1            149.1        165.7            92          90
#   13   PartialEmbeded              3.4              3.4          3.4            29          29

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-8j2c{background-color:#5B9BD5;color:#FFF;font-weight:bold;text-align:left;vertical-align:bottom}
# .tg .tg-jlny{background-color:#0FF;color:#000000;text-align:left;vertical-align:bottom}
# .tg .tg-xs60{background-color:#0F0;color:#000000;text-align:left;vertical-align:bottom}
# .tg .tg-2j5i{background-color:#800080;color:#ffffff;text-align:left;vertical-align:bottom}
# .tg .tg-iire{background-color:#ffffff;color:#000000;text-align:left;vertical-align:bottom}
# .tg .tg-7qj6{background-color:#FF0;color:#000000;text-align:left;vertical-align:bottom}
# .tg .tg-cxo5{background-color:#1E961E;color:#ffffff;text-align:left;vertical-align:bottom}
# .tg .tg-plz0{background-color:#00F;color:#ffffff;text-align:left;vertical-align:bottom}
# .tg .tg-q4ga{background-color:#FF8080;color:#000000;text-align:left;vertical-align:bottom}
# </style>
# <table class="tg"><thead>
#   <tr>
#     <th class="tg-8j2c">ROI</th>
#     <th class="tg-8j2c">Structure ID</th>
#     <th class="tg-8j2c">Color</th>
#     <th class="tg-8j2c">Volume (cm3)</th>
#   </tr></thead>
# <tbody>
#   <tr>
#     <td class="tg-iire">1</td>
#     <td class="tg-xs60">BODY</td>
#     <td class="tg-iire">Lime</td>
#     <td class="tg-iire">8043</td>
#   </tr>
#   <tr>
#     <td class="tg-iire">2</td>
#     <td class="tg-7qj6">AdjacentSpheres</td>
#     <td class="tg-iire">Yellow</td>
#     <td class="tg-iire">130.8</td>
#   </tr>
#   <tr>
#     <td class="tg-iire">3</td>
#     <td class="tg-cxo5">AdjacentShells</td>
#     <td class="tg-iire">Dark Green</td>
#     <td class="tg-iire">65.9</td>
#   </tr>
#   <tr>
#     <td class="tg-iire">4</td>
#     <td class="tg-2j5i">Surrounds</td>
#     <td class="tg-iire">Purple</td>
#     <td class="tg-iire">235.9</td>
#   </tr>
#   <tr>
#     <td class="tg-iire">5</td>
#     <td class="tg-plz0">Embeds</td>
#     <td class="tg-iire">Blue</td>
#     <td class="tg-iire">14.1</td>
#   </tr>
#   <tr>
#     <td class="tg-iire">6</td>
#     <td class="tg-jlny">PartialEmbeded</td>
#     <td class="tg-iire">Cyan</td>
#     <td class="tg-iire">3.4</td>
#   </tr>
#   <tr>
#     <td class="tg-iire">7</td>
#     <td class="tg-q4ga">PartialSurround</td>
#     <td class="tg-iire">Pink</td>
#     <td class="tg-iire">130.2</td>
#   </tr>
# </tbody></table>

# %%
# Calculate relationships between all structures
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()

print(f"Total relationships calculated: {structure_set.relationship_graph.number_of_edges()}")
# Out:
# === Calculating Structure Relationships ===
# Total relationships calculated: 21

# %%
# Display the relationship summary table
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
relationship_summary
# Out:
# === Structure Relationship Summary Table ===
# Structure_B      BODY OverlappedSphere OverlappedShells Surrounds     Embeds  \
# Structure_A
# BODY                =         Contains         Contains  Contains   Contains
# OverlappedSphere                     =
# OverlappedShells                                      =
# Surrounds                                                       =  Surrounds
# Embeds                                                                     =
# PartialSurround
# PartialEmbeded
#
# Structure_B      PartialSurround PartialEmbeded
# Structure_A
# BODY                   Partition       Contains
# OverlappedSphere
# OverlappedShells
# Surrounds
# Embeds
# PartialSurround                =       Shelters
# PartialEmbeded                                =

# %% [markdown]
# <img src="../Images/MultiVolume_A.png" alt="MultiVolume_A" width="600"/>
# ![MultiVolume_A](<../Images/MultiVolume_A.png>)

# %%
# Demonstrate structure filtering with exclusions
print("\n=== Structure Filtering Example ===")

# Load the DICOM structure file using file_name parameter
filtered_dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)

# Apply exclusions to remove structures starting with common prefixes
filtered_dicom_file.filter_exclusions(
    exclude_prefixes=['BODY', 'External'],
    case_sensitive=False,
    exclude_empty=True)

# Create a new StructureSet with exclusions applied
filtered_structure_set = StructureSet(dicom_structure_file=filtered_dicom_file)

print(f"Structures before filtering: {len(structure_set.structures)}")
print(f"Structures after filtering: {len(filtered_structure_set.structures)}")

if len(filtered_structure_set.structures) > 0:
    print("\n=== Remaining Structures After Filtering ===")
    for roi, structure in filtered_structure_set.structures.items():
        print(f"ROI {roi}: {structure.name}")

    # Calculate relationships for the filtered set
    filtered_structure_set.calculate_relationships()

    if filtered_structure_set.relationship_graph.number_of_edges() > 0:
        print("\n=== Filtered Relationship Summary ===")
        filtered_relationships = filtered_structure_set.relationship_summary()
        print(filtered_relationships)
else:
    print("All structures were filtered out.")
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# === Structure Filtering Example ===
# INFO:dicom:Extracted 730 contours from 7 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Filtered 201 contours from 1 excluded ROIs. Remaining: 529 contours from 6 ROIs
# INFO:structure_set:Building StructureSet from 529 contour points
# Structures before filtering: 7
# Structures after filtering: 6
#
# === Remaining Structures After Filtering ===
# ROI 7: OverlappedSphere
# ROI 8: OverlappedShells
# ROI 9: Surrounds
# ROI 10: Embeds
# ROI 12: PartialSurround
# ROI 13: PartialEmbeded
#
# === Filtered Relationship Summary ===
# ...

# %%
contour_points = pd.DataFrame(dicom_file.contour_points)
contour_points.set_index(['ROI', 'Slice'], inplace=True)
contour_points = contour_points.explode('Points')
def parse_point(row: pd.Series) -> pd.Series:
    new_row = row.copy()
    coords = row.Points
    new_row['X'] = coords[0]
    new_row['Y'] = coords[1]
    new_row['Z'] = coords[2]
    return new_row
contour_points = contour_points.apply(parse_point, axis=1)
contour_points.drop(columns=['Points'], inplace=True)
contour_points.reset_index(inplace=True)

contour_points['x_diff'] = contour_points.groupby(['ROI', 'Slice'])['X'].diff().abs()
contour_points['y_diff'] = contour_points.groupby(['ROI', 'Slice'])['Y'].diff().abs()
contour_points[['x_diff', 'y_diff']].describe().round(3)
# Out:
#            x_diff      y_diff
# count  210525.000  210525.000
# mean        0.062       0.060
# std         0.107       0.099
# min         0.000       0.000
# 25%         0.000       0.000
# 50%         0.055       0.049
# 75%         0.117       0.117
# max         5.077       4.098

# %% [markdown]
# ![Embeds Resolution](../Images/Resolution/EmbedsResolution.png)

# %%
contour_points.hist(['x_diff', 'y_diff'], bins=np.arange(0.01, .15, 0.001))
#contour_points.y_diff.hist(bins=np.arange(0.05, .25, 0.001))
plt.show()

# %% [markdown]
# ## Examine other structure files

# %%
test_file_name = 'RS.GJS_Struct_Tests.BRBL BH.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
print(f"Successfully loaded: {dicom_file}")
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=dicom_file)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.BRBL BH.dcm
# === Loading DICOM file ===: RS.GJS_Struct_Tests.BRBL BH.dcm
# INFO:dicom:Extracted 626 contours from 10 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.BRBL BH.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:structure_set:Building StructureSet from 626 contour points
# Successfully loaded: DICOM RT Structure: BRBL BH for patient GJS_Struct_Tests
# === Creating StructureSet from DicomStructureFile ===
#
# === Calculating Structure Relationships ===
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: divide by zero encountered in relate
#   return lib.relate(a, b, **kwargs)
# ...

# %%
contour_points = pd.DataFrame(dicom_file.contour_points)
contour_points.set_index(['ROI', 'Slice'], inplace=True)
contour_points = contour_points.explode('Points')
def parse_point(row: pd.Series) -> pd.Series:
    new_row = row.copy()
    coords = row.Points
    new_row['X'] = coords[0]
    new_row['Y'] = coords[1]
    new_row['Z'] = coords[2]
    return new_row
contour_points = contour_points.apply(parse_point, axis=1)
contour_points.drop(columns=['Points'], inplace=True)
contour_points.reset_index(inplace=True)

contour_points['x_diff'] = contour_points.groupby(['ROI', 'Slice'])['X'].diff().abs()
contour_points['y_diff'] = contour_points.groupby(['ROI', 'Slice'])['Y'].diff().abs()
contour_points[['x_diff', 'y_diff']].describe().round(3)
# Out:
#            x_diff      y_diff
# count  170285.000  170285.000
# mean        0.164       0.124
# std         0.481       0.254
# min         0.000       0.000
# 25%         0.068       0.038
# 50%         0.137       0.099
# 75%         0.273       0.201
# max        32.035      26.708

# %%
contour_points.hist(['x_diff', 'y_diff'], bins=np.arange(0.01, .3, 0.001))
#contour_points.y_diff.hist(bins=np.arange(0.05, .25, 0.001))
plt.show()

# %%
test_file_name = 'RS.1.2.246.352.221.506802614516650949923693429510578325.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
print(f"Successfully loaded: {dicom_file}")
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=dicom_file)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.1.2.246.352.221.506802614516650949923693429510578325.dcm
# === Loading DICOM file ===: RS.1.2.246.352.221.506802614516650949923693429510578325.dcm
# INFO:dicom:Extracted 3039 contours from 28 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.1.2.246.352.221.506802614516650949923693429510578325.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:structure_set:Building StructureSet from 3039 contour points
# Successfully loaded: DICOM RT Structure: LUNL for patient GJS_Struct_LUNG
# === Creating StructureSet from DicomStructureFile ===
#
# === Calculating Structure Relationships ===
# ...

# %%
contour_points = pd.DataFrame(dicom_file.contour_points)
contour_points.set_index(['ROI', 'Slice'], inplace=True)
contour_points = contour_points.explode('Points')
def parse_point(row: pd.Series) -> pd.Series:
    new_row = row.copy()
    coords = row.Points
    new_row['X'] = coords[0]
    new_row['Y'] = coords[1]
    new_row['Z'] = coords[2]
    return new_row
contour_points = contour_points.apply(parse_point, axis=1)
contour_points.drop(columns=['Points'], inplace=True)
contour_points.reset_index(inplace=True)

contour_points['x_diff'] = contour_points.groupby(['ROI', 'Slice'])['X'].diff().abs()
contour_points['y_diff'] = contour_points.groupby(['ROI', 'Slice'])['Y'].diff().abs()
contour_points[['x_diff', 'y_diff']].describe().round(3)
# Out:
#            x_diff      y_diff
# count  622296.000  622296.000
# mean        0.182       0.075
# std         0.904       0.148
# min         0.000       0.000
# 25%         0.076       0.000
# 50%         0.212       0.038
# 75%         0.234       0.125
# max        51.193      23.149

# %%
contour_points.hist(['x_diff', 'y_diff'], bins=np.arange(0.05, .25, 0.001))
#contour_points.y_diff.hist(bins=np.arange(0.05, .25, 0.001))
plt.show()

# %%
test_file_name = 'RS.NormalTissueTest.SPIL2.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
print(f"Successfully loaded: {dicom_file}")
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=dicom_file)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.NormalTissueTest.SPIL2.dcm
# === Loading DICOM file ===: RS.NormalTissueTest.SPIL2.dcm
# INFO:dicom:Extracted 1870 contours from 24 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.NormalTissueTest.SPIL2.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:structure_set:Building StructureSet from 1870 contour points
# Successfully loaded: DICOM RT Structure: SPIL2 for patient NormalTissueTest
# === Creating StructureSet from DicomStructureFile ===
#
# === Calculating Structure Relationships ===
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: divide by zero encountered in relate
#   return lib.relate(a, b, **kwargs)
# ...

# %%
contour_points = pd.DataFrame(dicom_file.contour_points)
contour_points.set_index(['ROI', 'Slice'], inplace=True)
contour_points = contour_points.explode('Points')
def parse_point(row: pd.Series) -> pd.Series:
    new_row = row.copy()
    coords = row.Points
    new_row['X'] = coords[0]
    new_row['Y'] = coords[1]
    new_row['Z'] = coords[2]
    return new_row
contour_points = contour_points.apply(parse_point, axis=1)
contour_points.drop(columns=['Points'], inplace=True)
contour_points.reset_index(inplace=True)

contour_points['x_diff'] = contour_points.groupby(['ROI', 'Slice'])['X'].diff().abs()
contour_points['y_diff'] = contour_points.groupby(['ROI', 'Slice'])['Y'].diff().abs()
contour_points[['x_diff', 'y_diff']].describe().round(3)
# Out:
#            x_diff      y_diff
# count  655585.000  655585.000
# mean        0.155       0.063
# std         0.923       0.204
# min         0.000       0.000
# 25%         0.063       0.000
# 50%         0.195       0.029
# 75%         0.195       0.101
# max        51.420      20.025

# %%
contour_points.hist(['x_diff', 'y_diff'], bins=np.arange(0.05, .25, 0.001))
#contour_points.y_diff.hist(bins=np.arange(0.05, .25, 0.001))
plt.show()

# %%
test_file_name = 'RS.GJS_Struct_Tests.ResolutionChecks.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
print(f"Successfully loaded: {dicom_file}")
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=dicom_file)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.ResolutionChecks.dcm
# === Loading DICOM file ===: RS.GJS_Struct_Tests.ResolutionChecks.dcm
# INFO:dicom:Extracted 155 contours from 5 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.ResolutionChecks.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:structure_set:Building StructureSet from 155 contour points
# Successfully loaded: DICOM RT Structure: ResolutionChecks for patient GJS_Struct_Tests
# === Creating StructureSet from DicomStructureFile ===
# ---------------------------------------------------------------------------
# InvalidContour                            Traceback (most recent call last)
# Cell In[28], line 10
# ...

# %% [markdown]
# ![Resolution Comparison](../Images/Resolution/ResolutionComparison.png)

# %%
contour_points.hist(['x_diff', 'y_diff'], bins=np.arange(0.001, .01, 0.001))
#contour_points.y_diff.hist(bins=np.arange(0.05, .25, 0.001))
plt.show()

# %% [markdown]
# #### Structure Vs Volume Resolution
# ##### Surrounds Image Set
# ![Embeds Resolution](../Images/Resolution/EmbedsResolution.png)
#
# - Surrounds Structure Resolution: 0.1172 cm
# - Surrounds Volume Resolution: 0.0586 cm
# - 0.0586 x 2 = 0.1172
#
# ![Surrounds Volume Resolution](../Images/Resolution/SurroundsVolumeResolution.png)
#
# - Volume width = Volume height = 20 cm
# - Volume Diameter = $\sqrt{20^2 + 20^2} = 28.284 cm$
# - Volume Resolution = 28.284 / 512 = 0.0553 cm
#
# ##### Resolution Tests Image Set
# ![Resolution Tests](../Images/Resolution/ResolutionComparison.png)
#
# - Resolution Tests Low Resolution: 0.0059 cm
# - Resolution Tests High Resolution: 0.0029 cm
# - Resolution Tests Volume Resolution: 0.0029 cm
# - 0.0029 x 2 = 0.0058 cm (rounding error)
#
# ![Resolution Tests Volume Resolution](../Images/Resolution/ResolutionTestsVolumeResolution.png)
#
# - Volume width = Volume height = 1 cm
# - Volume Diameter = $\sqrt{1^2 + 1^2} = 1.414 cm$
# - Volume Resolution = 1.414 / 512 = 0.0028 cm

# %% [markdown]
# ### Resolution Estimates
# 1. Get the Image diameter for the Structure Set
#     1. If reference image can be located, get image Diameter from the image.
#     2. If reference image cannot be located, use the maximum of the width or height from the Body Contour.
#         image diameters is then calculated as: $\sqrt{distance^2 + distance^2}$
#
# 2. Get number of pixels in the largest dimension (width or height)
#     1. If reference image can be located, get # pixels from the image.
#     2. If reference image cannot be located, use the default of 512 pixels.
# 3. Image Resolution = Image Diameter / Number of Pixels * 2
# 4. use this to round all polygons

# %% [markdown]
# ## Summary of Integration
#
# This extended demonstration shows how the `DicomStructureFile` class integrates seamlessly with the `StructureSet` class to provide:
#
# 1. **Automatic Structure Loading**: The `StructureSet` can be initialized directly from a `DicomStructureFile`
# 2. **Relationship Analysis**: Calculate spatial relationships between all structures
# 3. **Structure Filtering**: Apply exclusion patterns to remove unwanted structures
# 4. **Comprehensive Reporting**: Generate detailed reports on structure properties and relationships
# 5. **Data Export**: Export relationship data and analysis reports to various formats
#
# ### Key Benefits:
# - **Streamlined Workflow**: Single initialization creates both contour data and structure relationships
# - **Flexible Filtering**: Remove common utility structures (BODY, External, etc.) before analysis
# - **Rich Metadata**: Access both DICOM metadata and calculated structure properties
# - **Export Capabilities**: Generate reports and data files for further analysis
#
# This integration demonstrates the power of combining DICOM file handling with advanced spatial relationship analysis.

# %% [markdown]
# ## Summary
#
# This notebook has demonstrated the complete functionality of the `DicomStructureFile` class:
#
# 1. **Loading DICOM Files**: Successfully loaded a DICOM RT Structure file using either file_name or file_path parameters
# 2. **Metadata Extraction**: Retrieved comprehensive structure file information and ROI details
# 3. **Contour Processing**: Extracted all contour sequences and converted them to `ContourPoints` objects
#
# ### Key Features Demonstrated:
# - Flexible initialization with multiple parameter options
# - Robust error handling and validation
# - Integration with existing `ContourPoints` and related classes
# - Comprehensive metadata extraction
# - Multiple export format support
#
# ### Next Steps:
# - The `DicomStructureFile` class can be integrated into larger workflow pipelines

# %% [markdown]
# ## Resolution Calculation from Image File
#
# Let's demonstrate the new methods added to DicomStructureFile:
# 1. `find_image_files()` - Find corresponding image files
# 2. `calculate_structure_resolution()` - Calculate structure resolution
# 3. `resolution` attribute - Automatically calculated resolution
# 4. Automatic contour point rounding based on resolution

# %% [markdown]
# ### 1: Finding Corresponding Image Files

# %%
# Load the RS.BREL_TEST.BREL BH.dcm file to demo new methods
test_file = "RS.BREL_TEST.BREL BH.dcm"
test_dicom = DicomStructureFile(top_dir=tests_dir, file_name=test_file)

print(f"Loaded DICOM structure file: {test_dicom}")
print(f"Structure Set: {test_dicom.structure_set_info['StructureSet']}")
print(f"Patient ID: {test_dicom.structure_set_info['PatientID']}")
print(f"Number of contours: {len(test_dicom.contour_points)}")
print(f"Calculated resolution: {test_dicom.resolution} cm/pixel")
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.BREL_TEST.BREL BH.dcm
# INFO:dicom:Extracted 793 contours from 11 ROIs
# INFO:dicom:Found 3 frame-of-reference matches and 0 other matches for structure set RS.BREL_TEST.BREL BH.dcm
# INFO:dicom:Calculated resolution: 0.1 cm/pixel from image CT.BREL_TEST.Image 1.dcm
# Loaded DICOM structure file: DICOM RT Structure: BREL BH for patient BREL_TEST
# Structure Set: BREL BH
# Patient ID: BREL_TEST
# Number of contours: 793
# Calculated resolution: 0.1 cm/pixel

# %%
# Demo the find_image_files method
print("Searching for corresponding image files...")
image_files = test_dicom.find_image_files()

print(f"\nFound {len(image_files)} matching image files:")
for i, img_file in enumerate(image_files[:5]):  # Show first 5
    print(f"  {i+1}. {img_file.name}")

if len(image_files) > 5:
    print(f"  ... and {len(image_files) - 5} more files")

# Try with specific modalities
ct_files = test_dicom.find_image_files(modalities=['CT'])
print(f"\nCT files specifically: {len(ct_files)} found")

mr_files = test_dicom.find_image_files(modalities=['MR'])
print(f"MR files specifically: {len(mr_files)} found")
# Out:
# INFO:dicom:Found 3 frame-of-reference matches and 0 other matches for structure set RS.BREL_TEST.BREL BH.dcm
# INFO:dicom:Found 3 frame-of-reference matches and 0 other matches for structure set RS.BREL_TEST.BREL BH.dcm
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.BREL_TEST.BREL BH.dcm
# Searching for corresponding image files...
#
# Found 3 matching image files:
#   1. CT.BREL_TEST.Image 1.dcm
#   2. CT.BREL_TEST.Image 135.dcm
#   3. CT.BREL_TEST.Image 70.dcm
#
# CT files specifically: 3 found
# MR files specifically: 0 found

# %% [markdown]
# ### 2. Resolution Calculation Details

# %%
# Demo resolution calculation
print("Resolution Calculation Details:")
print(f"Automatic resolution (attribute): {test_dicom.resolution} cm/pixel")

# Calculate resolution manually to see the process
manual_resolution = test_dicom.calculate_structure_resolution()
print(f"Manual calculation result: {manual_resolution} cm/pixel")

# Try resolution calculation from structure dimensions (fallback method)
print("\nTesting fallback method (structure-based resolution):")
structure_resolution = test_dicom._calculate_resolution_from_structures()
print(f"Structure-based resolution: {structure_resolution} cm/pixel")

# Show which structures might be used for resolution calculation
structure_names = test_dicom.get_structure_names()
print(f"\nAvailable structures for resolution calculation:")
body_structures = []
for roi_num, name in structure_names.items():
    name_upper = name.upper()
    if any(target in name_upper for target in ['BODY', 'EXTERNAL', 'PATIENT', 'SKIN']):
        body_structures.append((roi_num, name))
        print(f"  ROI {roi_num}: {name} ✓ (suitable for resolution)")
    elif len(body_structures) < 3:  # Show a few other structures for context
        print(f"  ROI {roi_num}: {name}")

if not body_structures:
    print("  No BODY/EXTERNAL structures found - would use default assumptions")
# Out:
# INFO:dicom:Found 3 frame-of-reference matches and 0 other matches for structure set RS.BREL_TEST.BREL BH.dcm
# INFO:dicom:Calculated resolution: 0.1 cm/pixel from image CT.BREL_TEST.Image 1.dcm
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# Resolution Calculation Details:
# Automatic resolution (attribute): 0.1 cm/pixel
# Manual calculation result: 0.1 cm/pixel
#
# Testing fallback method (structure-based resolution):
# Structure-based resolution: 0.1 cm/pixel
#
# Available structures for resolution calculation:
#   ROI 3: Heart
#   ROI 4: Lung B
#   ROI 5: Lung L
#   ROI 6: Lung R
#   ROI 9: BODY ✓ (suitable for resolution)
#   ROI 10: DPV
#   ROI 15: Scar Wire
#   ROI 14: PTV Cavity
#   ROI 13: eval PTV
#   ROI 12: CTV Cavity
#   ROI 11: Cavity

# %% [markdown]
# ### Summary of new DicomStructureFile Features

# %%
# Compare the enhanced functionality
print("=== Enhanced DicomStructureFile Summary ===")
print(f"File: {test_dicom.file_name}")
print(f"Patient: {test_dicom.structure_set_info['PatientID']}")
print(f"Structure Set: {test_dicom.structure_set_info['StructureSet']}")
print()
print("NEW FEATURES:")
print(f"✓ Automatic resolution calculation: {test_dicom.resolution} cm/pixel")
print(f"✓ Found {len(test_dicom.find_image_files())} corresponding image files")
print(f"✓ Contour points automatically rounded to resolution tolerance")
print(f"✓ {len(test_dicom.contour_points)} contours loaded and processed")
print()

# Show the workflow advantages
print("WORKFLOW ADVANTAGES:")
print("1. Resolution is calculated automatically during object creation")
print("2. No need to manually search for related image files")
print("3. Contour coordinates are automatically aligned to appropriate tolerance")
print("4. Fallback methods ensure resolution is calculated even without image files")
print("5. All processing is logged for transparency and debugging")

# Show structure names for context
print(f"\nStructures available in this file:")
for roi_num, name in list(test_dicom.structure_names.items())[:10]:
    print(f"  ROI {roi_num}: {name}")
if len(test_dicom.structure_names) > 10:
    print(f"  ... and {len(test_dicom.structure_names) - 10} more structures")
# Out:
# INFO:dicom:Found 3 frame-of-reference matches and 0 other matches for structure set RS.BREL_TEST.BREL BH.dcm
# === Enhanced DicomStructureFile Summary ===
# File: RS.BREL_TEST.BREL BH.dcm
# Patient: BREL_TEST
# Structure Set: BREL BH
#
# NEW FEATURES:
# ✓ Automatic resolution calculation: 0.1 cm/pixel
# ✓ Found 3 corresponding image files
# ✓ Contour points automatically rounded to resolution tolerance
# ✓ 793 contours loaded and processed
#
# WORKFLOW ADVANTAGES:
# 1. Resolution is calculated automatically during object creation
# 2. No need to manually search for related image files
# 3. Contour coordinates are automatically aligned to appropriate tolerance
# 4. Fallback methods ensure resolution is calculated even without image files
# 5. All processing is logged for transparency and debugging
#
# Structures available in this file:
#   ROI 3: Heart
#   ROI 4: Lung B
#   ROI 5: Lung L
#   ROI 6: Lung R
#   ROI 9: BODY
#   ROI 10: DPV
#   ROI 15: Scar Wire
#   ROI 14: PTV Cavity
# ...

# %%
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=test_dicom)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:structure_set:Building StructureSet from 793 contour points
# === Creating StructureSet from DicomStructureFile ===
#
# === Calculating Structure Relationships ===
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: divide by zero encountered in relate
#   return lib.relate(a, b, **kwargs)
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: invalid value encountered in relate
#   return lib.relate(a, b, **kwargs)
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: divide by zero encountered in relate
#   return lib.relate(a, b, **kwargs)
# === Structure Relationship Summary Table ===
# Structure_B     Heart    Lung B    Lung L    Lung R      BODY    Cavity  \
# Structure_A
# Heart               =  Overlaps   Borders  Overlaps  Overlaps
# Lung B       Overlaps         =  Overlaps  Overlaps  Overlaps
# ...

# %% [markdown]
# ## Use Calculated Resolution for Relationship Testing

# %%
# Load the RS.BREL_TEST.BREL BH.dcm file to demo new methods
test_file = "RS.BREL_TEST.BREL BH.dcm"
test_dicom = DicomStructureFile(top_dir=tests_dir, file_name=test_file)

print(f"Loaded DICOM structure file: {test_dicom}")
print(f"Structure Set: {test_dicom.structure_set_info['StructureSet']}")
print(f"Patient ID: {test_dicom.structure_set_info['PatientID']}")
print(f"Number of contours: {len(test_dicom.contour_points)}")
print(f"Calculated resolution: {test_dicom.resolution} cm/pixel")
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.BREL_TEST.BREL BH.dcm
# INFO:dicom:Extracted 793 contours from 11 ROIs
# INFO:dicom:Found 3 frame-of-reference matches and 0 other matches for structure set RS.BREL_TEST.BREL BH.dcm
# INFO:dicom:Calculated resolution: 0.1 cm/pixel from image CT.BREL_TEST.Image 1.dcm
# Loaded DICOM structure file: DICOM RT Structure: BREL BH for patient BREL_TEST
# Structure Set: BREL BH
# Patient ID: BREL_TEST
# Number of contours: 793
# Calculated resolution: 0.1 cm/pixel

# %%
test_file_name = 'RS.NormalTissueTest.SPIL2.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
print(f"Successfully loaded: {dicom_file}")
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=dicom_file)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.NormalTissueTest.SPIL2.dcm
# === Loading DICOM file ===: RS.NormalTissueTest.SPIL2.dcm
# INFO:dicom:Extracted 1870 contours from 24 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.NormalTissueTest.SPIL2.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:structure_set:Building StructureSet from 1870 contour points
# Successfully loaded: DICOM RT Structure: SPIL2 for patient NormalTissueTest
# === Creating StructureSet from DicomStructureFile ===
#
# === Calculating Structure Relationships ===
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: divide by zero encountered in relate
#   return lib.relate(a, b, **kwargs)
# ...

# %%
test_file_name = 'RS.GJS_Struct_Tests.BRBL BH.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
print(f"Successfully loaded: {dicom_file}")
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=dicom_file)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.BRBL BH.dcm
# === Loading DICOM file ===: RS.GJS_Struct_Tests.BRBL BH.dcm
# INFO:dicom:Extracted 626 contours from 10 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.BRBL BH.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:structure_set:Building StructureSet from 626 contour points
# Successfully loaded: DICOM RT Structure: BRBL BH for patient GJS_Struct_Tests
# === Creating StructureSet from DicomStructureFile ===
#
# === Calculating Structure Relationships ===
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: divide by zero encountered in relate
#   return lib.relate(a, b, **kwargs)
# ...

# %%
test_file_name = "RS.GJS_Struct_Tests.MultiVolume_A (1).dcm"
#test_file_name = "RS.GJS_Struct_Tests.Relations.dcm"

# %%
# Load the DICOM structure file using file_name parameter
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)

print(f"Successfully loaded: {dicom_file}")
print(f"File name: {dicom_file.file_name}")
print(f"Is RT Structure file: {dicom_file.is_structure_file()}")
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# INFO:dicom:Extracted 730 contours from 7 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# Successfully loaded: DICOM RT Structure: MultiVolume_A for patient GJS_Struct_Tests
# File name: RS.GJS_Struct_Tests.MultiVolume_A (1).dcm
# Is RT Structure file: True

# %% [markdown]
# ## Demonstrate errors in contours produced by rounding

# %%
def points_to_polygon(points: List[Tuple[float, float]]) -> shapely.Polygon:
    '''The points_to_polygon function without validation testing'''
    if not points:
        return shapely.Polygon()
    polygon = shapely.Polygon(points)
    return polygon


# Define the path to the test DICOM file
tests_dir = Path.cwd() / r'Tests'
tests_dir = tests_dir.resolve()
test_file_name = 'RS.GJS_Struct_Tests.BRBL BH.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
filtered_contours = dicom_file.filter_exclusions()

dicom_file.structure_names
slice_data = dicom_file.contour_points
contour_table = pd.DataFrame(slice_data)

structure_names_dict = dicom_file.structure_names
structure_names = pd.Series(structure_names_dict, name='StructureName')
structure_names.index.name = 'ROI'
contour_table = contour_table.join(structure_names, on='ROI', how='left')

# Round contour points
dicom_file.round_contour_points()

# Create polygons and calculate areas
contour_table['Polygon'] = contour_table['Points'].apply(points_to_polygon)
contour_table['Area'] = contour_table['Polygon'].apply(lambda poly: poly.area)

# Identify invalid contours
contour_table['IsValid'] = contour_table['Polygon'].apply(shapely.is_valid_reason)
valid_contours = contour_table.IsValid.str.contains('Valid')
selected_columns = ['StructureName', 'ROI', 'Slice', 'IsValid', 'Points']
invalid_contours = contour_table.loc[~valid_contours,selected_columns]
invalid_contours.sort_values(by=['IsValid', 'StructureName'], inplace=True)
print('\nContour Errors:')
print(invalid_contours[['StructureName', 'Slice', 'IsValid']])

print(invalid_contours[invalid_contours.Slice==0.0].Points.tolist())
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.BRBL BH.dcm
# === Loading DICOM file ===: RS.GJS_Struct_Tests.BRBL BH.dcm
# INFO:dicom:Extracted 626 contours from 10 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.BRBL BH.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Filtered 0 contours from 1 excluded ROIs. Remaining: 626 contours from 9 ROIs
# INFO:dicom:Rounded 626 contours to resolution of 0.1 cm/pixel
# Contour Errors:
# Empty DataFrame
# Columns: [StructureName, Slice, IsValid]
# Index: []
# []

# %% [markdown]
# # Incorrect relations?

# %%
test_file_name = 'RS.GJS_Struct_Tests.BRBL BH.dcm'

print(f"=== Loading DICOM file ===: {test_file_name}")
dicom_file = DicomStructureFile(
    top_dir=tests_dir,
    file_name=test_file_name
)
print(f"Successfully loaded: {dicom_file}")
print("=== Creating StructureSet from DicomStructureFile ===")
structure_set = StructureSet(dicom_structure_file=dicom_file)
print("\n=== Calculating Structure Relationships ===")
structure_set.calculate_relationships()
print("\n=== Structure Relationship Summary Table ===")
symbol_map = {RelationshipType.UNKNOWN: '?',
              RelationshipType.DISJOINT: '',
              RelationshipType.EQUALS: '='
        }
relationship_summary = structure_set.relationship_summary(symbol_map=symbol_map)
#print(relationship_summary)
relationship_summary
# Out:
# INFO:dicom:Successfully loaded DICOM dataset from RS.GJS_Struct_Tests.BRBL BH.dcm
# === Loading DICOM file ===: RS.GJS_Struct_Tests.BRBL BH.dcm
# INFO:dicom:Extracted 626 contours from 10 ROIs
# INFO:dicom:Found 0 frame-of-reference matches and 0 other matches for structure set RS.GJS_Struct_Tests.BRBL BH.dcm
# WARNING:dicom:No matching image files found, attempting to use structure dimensions
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:dicom:Calculated resolution from structure 'BODY': 0.1 cm/pixel
# INFO:structure_set:Building StructureSet from 626 contour points
# Successfully loaded: DICOM RT Structure: BRBL BH for patient GJS_Struct_Tests
# === Creating StructureSet from DicomStructureFile ===
#
# === Calculating Structure Relationships ===
# d:\.conda\envs\StructureRelations\Lib\site-packages\shapely\predicates.py:1171: RuntimeWarning: divide by zero encountered in relate
#   return lib.relate(a, b, **kwargs)
# ...
